# %% [markdown]
# ## 0. Download from kaggle

# %%
# !pip install kaggle

# %%
# !kaggle datasets download -d sagyamthapa/nepali-housing-price-dataset
# Out:
# Dataset URL: https://www.kaggle.com/datasets/sagyamthapa/nepali-housing-price-dataset
# License(s): GPL-2.0
# ...
#   0%|          | 0.00/90.7k [00:00<?, ?B/s]
# 100%|##########| 90.7k/90.7k [00:00<00:00, 68.2MB/s]

# %%
import zipfile

# %%
path="nepali-housing-price-dataset.zip"

# %%
with zipfile.ZipFile(path, 'r') as zipped:
    zipped.extractall("datasets")

# %%
import pandas as pd

# %%
df= pd.read_csv("datasets/2020-4-27.csv")

# %%
df.head(3)
# Out:
#                                                Title  \
# 0  Flat System House On Sale At Budhanikantha : H...
# 1  21 Aana Beautiful House : House For Sale In Bu...
# 2  Beautiful To Floor House : House For Sale In D...
#
#                                     Address       City     Price  Bedroom  \
# 0  Budhanikantha, Budhanilkantha, Kathmandu  Kathmandu  90000000        6
# 1        Pasikot, Budhanilkantha, Kathmandu  Kathmandu  80000000        5
# 2               Dhapasi, Dhapasi, Kathmandu  Kathmandu  70000000        5
#
#    Bathroom  Floors  Parking  Face    Year Views           Area  \
# 0         3     2.0       10  West  2073.0    17   1-0-0-0 Aana
# 1         3     2.0        9  East  2073.0    26  0-21-0-0 Aana
# 2         3     2.0       12  East  2071.0   154   1-1-0-0 Aana
#
#                     Road Road Width     Road Type     Build Area  \
# 0  20 Feet / Blacktopped   20 Feet    Blacktopped  18-0-0-0 Aana
# ...

# %% [markdown]
# ## 1. Read local CSV

# %%
df= pd.read_csv("datasets/2020-4-27.csv")

# %%
df.head()
# Out:
#                                                Title  \
# 0  Flat System House On Sale At Budhanikantha : H...
# 1  21 Aana Beautiful House : House For Sale In Bu...
# 2  Beautiful To Floor House : House For Sale In D...
# 3  Modern Architecture Bungalow House : House For...
# 4  Modern Bungalow House : House For Sale In Golf...
#
#                                     Address       City      Price  Bedroom  \
# 0  Budhanikantha, Budhanilkantha, Kathmandu  Kathmandu   90000000        6
# 1        Pasikot, Budhanilkantha, Kathmandu  Kathmandu   80000000        5
# 2               Dhapasi, Dhapasi, Kathmandu  Kathmandu   70000000        5
# 3           baluwatar, Baluwatar, Kathmandu  Kathmandu  130000000        6
# 4             Golfutar, Golfutar, Kathmandu  Kathmandu  100000000        6
#
#    Bathroom  Floors  Parking  Face    Year Views           Area  \
# 0         3     2.0       10  West  2073.0    17   1-0-0-0 Aana
# ...

# %% [markdown]
# ## 2. Read remote CSV

# %%
url= "https://gist.githubusercontent.com/kevin336/acbb2271e66c10a5b73aacf82ca82784/raw/e38afe62e088394d61ed30884dd50a6826eee0a8/employees.csv"

# %%
df= pd.read_csv(url)

# %%
df.head()
# Out:
#    EMPLOYEE_ID FIRST_NAME  LAST_NAME     EMAIL  PHONE_NUMBER  HIRE_DATE  \
# 0          198     Donald   OConnell  DOCONNEL  650.507.9833  21-JUN-07
# 1          199    Douglas      Grant    DGRANT  650.507.9844  13-JAN-08
# 2          200   Jennifer     Whalen   JWHALEN  515.123.4444  17-SEP-03
# 3          201    Michael  Hartstein  MHARTSTE  515.123.5555  17-FEB-04
# 4          202        Pat        Fay      PFAY  603.123.6666  17-AUG-05
#
#      JOB_ID  SALARY COMMISSION_PCT MANAGER_ID  DEPARTMENT_ID
# 0  SH_CLERK    2600             -         124             50
# 1  SH_CLERK    2600             -         124             50
# 2   AD_ASST    4400             -         101             10
# 3    MK_MAN   13000             -         100             20
# 4    MK_REP    6000             -         201             20

# %% [markdown]
# ## 3. Read from JSON

# %%
url= "https://dummyjson.com/posts"

# %%
data=pd.read_json(url).posts
df=pd.json_normalize(data)
df.head()
# Out:
#    id                                              title  \
# 0   1                   His mother had always taught him
# 1   2           He was an expert but not in a discipline
# 2   3  Dave watched as the forest burned up on the hill.
# 3   4                     All he wanted was a candy bar.
# 4   5             Hopes and dreams were dashed that day.
#
#                                                 body  \
# 0  His mother had always taught him not to ever t...
# 1  He was an expert but not in a discipline that ...
# 2  Dave watched as the forest burned up on the hi...
# 3  All he wanted was a candy bar. It didn't seem ...
# 4  Hopes and dreams were dashed that day. It shou...
#
#                            tags  views  userId  reactions.likes  \
# 0    [history, american, crime]    305     121              192
# 1    [french, fiction, english]   4884      91              859
# 2    [magical, history, french]   4152      16             1448
# ...

# %% [markdown]
# ## 4. Read from SQL

# %%
# !pip install sqlalchemy mysql-connector-python

# %%
from sqlalchemy import create_engine

# %%
engine= create_engine("mysql+mysqlconnector://root:@localhost/company")

# %%
df= pd.read_sql_query("SELECT * FROM employees", engine)

# %%
df.head()
# Out:
#    employee_id first_name last_name                         email   hire_date  \
# 0          101       John     Smith        john.smith@company.com  2018-06-15
# 1          102      Sarah   Johnson     sarah.johnson@company.com  2019-03-22
# 2          103    Michael  Williams  michael.williams@company.com  2020-11-05
# 3          104      Emily     Brown       emily.brown@company.com  2017-09-10
# 4          105      David     Jones       david.jones@company.com  2021-01-30
#
#    department_id   salary
# 0              1  75000.0
# 1              2  68000.0
# 2              3  82000.0
# 3              1  78000.0
# 4              4  65000.0

# %% [markdown]
# ## 5. Read from API

# %%
url="https://randomuser.me/api/?results=10"

# %%
import requests

# %%
response=requests.get(url)

# %%
data= response.json()['results']

# %%
df= pd.json_normalize(data)

# %%
df.head()
# Out:
#    gender                        email           phone            cell nat  \
# 0    male  nathan.robinson@example.com  (790)-682-8303  (655)-596-7798  NZ
# 1  female    eline.gautier@example.com  05-35-16-35-67  06-44-18-56-24  FR
# 2    male  koert.vanhengel@example.com   (0434) 869975   (06) 56985296  NL
# 3  female  parimala.shetty@example.com      7615029783      8088469614  IN
# 4    male     amando.doest@example.com   (011) 1815823   (06) 37914156  NL
#
#   name.title name.first   name.last  location.street.number  \
# 0         Mr     Nathan    Robinson                    7588
# 1         Ms      Eline     Gautier                    7868
# 2         Mr      Koert  Van Hengel                    4465
# 3         Ms   Parimala      Shetty                    6953
# 4         Mr     Amando       Doest                    2565
#
#   location.street.name  ...  \
# 0         Railway Road  ...
# 1             Rue Abel  ...
# 2             De Renne  ...
# 3   Gandhi Maidan Marg  ...
# ...
